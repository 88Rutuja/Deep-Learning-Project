# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/38/d2/3e8c13ffc37ca5ebc6f382b242b44acb43eb489042e1728407ac3904e72f/opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/38.1 MB 2.3 MB/s eta 0:00:17
#    ---------------------------------------- 0.4/38.1 MB 4.5 MB/s eta 0:00:09
#     --------------------------------------- 0.7/38.1 MB 5.5 MB/s eta 0:00:07
#    - -------------------------------------- 1.1/38.1 MB 6.2 MB/s eta 0:00:06
#    - -------------------------------------- 1.5/38.1 MB 7.0 MB/s eta 0:00:06
#    -- ------------------------------------- 2.0/38.1 MB 7.7 MB/s eta 0:00:05
#    -- ------------------------------------- 2.7/38.1 MB 8.5 MB/s eta 0:00:05
# ...

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image


from keras.models import Sequential
from keras.layers import Convolution2D  # convolution Layer
from keras.layers import MaxPooling2D   # Pooling Layer
from keras.layers import Flatten        # Flatten
from keras.layers import Dense
# Out:
# WARNING:tensorflow:From C:\Users\vedpa\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
 pip install --upgrade tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/93/21/9b035a4f823d6aee2917c75415be9a95861ff3d73a0a65e48edbf210cec1/tensorflow-2.15.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for tensorflow-intel==2.15.0 from https://files.pythonhosted.org/packages/4c/48/1a5a15517f18eaa4ff8d598b1c000300b20c1bb0e624539d702117a0c369/tensorflow_intel-2.15.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for absl-py>=1.0.0 from https://files.pythonhosted.org/packages/01/e4/dc0a1dcc4e74e08d7abedab278c795eef54a224363bb18f5692f416d834f/absl_py-2.0.0-py3-none-any.whl.metadata
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...

# %%
# Initialising the CNN
classifier = Sequential()

############# CNN - 1 ##################

# Step 1 - Convolution Layer
classifier.add(Convolution2D(32, 3, 3, input_shape = (64, 64, 3), activation = 'relu')) # calucaltion 

# Step 2 - Pooling Layer
classifier.add(MaxPooling2D(pool_size = (2, 2))) #  reduce the spatial size  two type of layer Avg & max layer



###  step 3 - Flattening Layer 

classifier.add(Flatten())        # conver  3D data to 1D data 

#################### Step 4 - Full connection  ( Neural Netwokr) ###################

classifier.add(Dense(units = 128, activation = 'relu'))   ## 1 HIDDEN LAYER WITH 128 NEURONS 
classifier.add(Dense(units = 1, activation = 'sigmoid'))   # relu use to convert -ve number into +ve number
# Out:
# WARNING:tensorflow:From C:\Users\vedpa\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\vedpa\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\vedpa\AppData\Roaming\Python\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 21, 21, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 10, 10, 32)        0
#  D)
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 128)               409728
#
#  dense_1 (Dense)             (None, 1)                 129
#
# ...
# Total params: 410753 (1.57 MB)
# Trainable params: 410753 (1.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
1.
# Part 2 - Fitting the CNN to the images

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255)  # max normilization
                                   

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(r"C:\Users\vedpa\Downloads\archive (9)\data\train",
                                                 target_size = (64, 64),  # HEIGHT AND WIDTH
                                                 batch_size = 32, # take 32 group which pick image randomly without replacement
                                                 class_mode = 'binary')  # binary because we have 2 type 

test_set = test_datagen.flow_from_directory(r"C:\Users\vedpa\Downloads\archive (9)\data\test",
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 7553 images belonging to 2 classes.
# Found 7553 images belonging to 2 classes.

# %%
training_set.class_indices
# Out:
# {'with_mask': 0, 'without_mask': 1}

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
result=classifier.fit(training_set,
                         epochs=20, # iteration or repeat 
                         validation_data = test_set)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\vedpa\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\vedpa\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 237/237 [==============================] - 428s 2s/step - loss: 0.3659 - accuracy: 0.8401 - val_loss: 0.2815 - val_accuracy: 0.8814
# Epoch 2/20
# 237/237 [==============================] - 88s 371ms/step - loss: 0.2424 - accuracy: 0.9079 - val_loss: 0.2032 - val_accuracy: 0.9237
# Epoch 3/20
# 237/237 [==============================] - 90s 378ms/step - loss: 0.2100 - accuracy: 0.9183 - val_loss: 0.1935 - val_accuracy: 0.9248
# Epoch 4/20
# ...

# %%
classifier.save('mask_detect_classifier.h5')

# %%
from  keras.models import load_model

from tensorflow.keras.preprocessing import image

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
import os 
os.chdir(r"C:\Users\vedpa\Downloads\archive (9)\data\live_data")

# %%
model=load_model("mask_detect_classifier.h5")

# %%
def model_output(path, model):
    raw_img = image.load_img(path, target_size=(64, 64))  # image is converted to 64*64
    
    raw_img = image.img_to_array(raw_img)    # convert image to array 
    
    raw_img = np.expand_dims(raw_img, axis=0)
    raw_img = raw_img / 255
    y_pred = model.predict(raw_img)
    
    predicted_class = int(y_pred[0][0] > 0.5)   # probability

    if predicted_class == 1:
        print("without_mask")
        return "without_mask"
    else:
        print("with_mask")
        return "with_mask"

# %%
def count_images_with_without_mask(directory_path, model):
    
    with_mask_count = 0
    without_mask_count = 0

    for filename in os.listdir(directory_path):
        
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(directory_path, filename)
            prediction = model_output(image_path, model)
            
            if prediction == "without_mask":
                without_mask_count += 1
            else:
                with_mask_count += 1

    return with_mask_count, without_mask_count

# %% [markdown]
# ## Count Total number of mask with and without mask

# %%
live_data_directory = (r"C:\Users\vedpa\Downloads\archive (9)\data\live_data")

with_mask_count, without_mask_count = count_images_with_without_mask(live_data_directory, model)
# Out:
# 1/1 [==============================] - 0s 79ms/step
# without_mask
# 1/1 [==============================] - 0s 17ms/step
# without_mask
# 1/1 [==============================] - 0s 16ms/step
# without_mask
# 1/1 [==============================] - 0s 17ms/step
# without_mask
# 1/1 [==============================] - 0s 20ms/step
# without_mask
# 1/1 [==============================] - 0s 20ms/step
# without_mask
# 1/1 [==============================] - 0s 18ms/step
# without_mask
# 1/1 [==============================] - 0s 17ms/step
# without_mask
# 1/1 [==============================] - 0s 17ms/step
# without_mask
# 1/1 [==============================] - 0s 17ms/step
# without_mask
# 1/1 [==============================] - 0s 17ms/step
# without_mask
# 1/1 [==============================] - 0s 20ms/step
# without_mask
# 1/1 [==============================] - 0s 21ms/step
# without_mask
# 1/1 [==============================] - 0s 18ms/step
# without_mask
# ...

# %%
print("Total number of bikers with mask:", with_mask_count)
print("Total number of bikers without mask:", without_mask_count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print("Total number of bikers with mask:", with_mask_count)
#       2 print("Total number of bikers without mask:", without_mask_count)
#
# NameError: name 'with_mask_count' is not defined

# %% [markdown]
# ## Result

# %% [markdown]
# ### 1.Total number of with mask : 18
# ### 2.Total number of without mask : 9

# %%
image_path = "without_mask_99.jpg"  
prediction_result = model_output(image_path, model)

# %%
 model_output("with_mask_977.jpg",model)

# %% [markdown]
# ## Detecte using VideoCapture

# %%
cap = cv2.VideoCapture(0)

# %%
while True:
    ret, frame = cap.read()
    
    img = cv2.resize(frame, (224, 224))
    
    ### call detect helmet method
    temp_img_path = 'temp_frame.jpg'  
    cv2.imwrite(temp_img_path, img)
    
    y_pred = model_output(temp_img_path,model)
          
    print(y_pred)

    if not ret:
        print("Failed to capture frame")
        break

    cv2.imshow("window", frame)

    # Check for user input every 1 millisecond
    key = cv2.waitKey(1) & 0xFF

    # Break the loop when the 'q' 
    if key == ord('q'):
        break

# Release the video capture and close OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 10
#       7 temp_img_path = 'temp_frame.jpg'
#       8 cv2.imwrite(temp_img_path, img)
# ---> 10 y_pred = model_output(temp_img_path,model)
#      12 print(y_pred)
#      14 if not ret:
#
# NameError: name 'model_output' is not defined
